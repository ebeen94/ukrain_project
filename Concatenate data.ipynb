# %% [markdown]
# # Concatenate Data and Save as 1 file

# %%
# import twint
# import nest_asyncio
import datetime
import pandas as pd
import json

# %%
data28 = pd.read_json('./data/UkraineRussia_28.json', lines = True)

# %%
data25 = pd.read_json('./data/UkraineRussia.json', lines = True)

# %%
#concatenate with ~25 data
df = pd.concat([data25, data28], axis=0)

# %%
df[df.duplicated(subset=['id','date','tweet'], keep=False)]
df
# Out:
#                          id      conversation_id                created_at  \
# 0       1497188084022083585  1497188084022083584 2022-02-25 13:33:50+01:00
# 1       1497188083065888841  1497188083065888768 2022-02-25 13:33:50+01:00
# 2       1497188081572716562  1497188081572716544 2022-02-25 13:33:49+01:00
# 3       1497188078385049602  1497188078385049600 2022-02-25 13:33:48+01:00
# 4       1497188074467602434  1497188074467602432 2022-02-25 13:33:48+01:00
# ...                     ...                  ...                       ...
# 156332  1496944053342113797  1496944053342113792 2022-02-24 21:24:08+01:00
# 156333  1496944034006601728  1496944034006601728 2022-02-24 21:24:04+01:00
# 156334  1496944018596499463  1496944018596499456 2022-02-24 21:24:00+01:00
# 156335  1496944003677401096  1496944003677401088 2022-02-24 21:23:57+01:00
# 156336  1496943988183547908  1496943988183547904 2022-02-24 21:23:53+01:00
#
#              date      time  timezone              user_id         username  \
# 0      2022-02-25  13:33:50       100             18071358   zeenewsenglish
# 1      2022-02-25  13:33:50       100           3248072657  wwiiletterlover
# 2      2022-02-25  13:33:49       100           2787284764      infofrance3
# 3      2022-02-25  13:33:48       100            419909890      ahmadekabir
# 4      2022-02-25  13:33:48       100  1310508002424885248        pollux_hh
# ...           ...       ...       ...                  ...              ...
# 156332 2022-02-24  21:24:08       100  1143239896993320960    peuplerevolte
# 156333 2022-02-24  21:24:04       100  1465263490407583748    africonnected
# 156334 2022-02-24  21:24:00       100           3214438509      austine9091
# 156335 2022-02-24  21:23:57       100            382844364  djelabababouche
# 156336 2022-02-24  21:23:53       100            302312898         ike_saul
#
#                                name place  ... geo source user_rt_id user_rt  \
# 0                  Zee News English        ...
# 1              Liz Gilmore Williams        ...
# 2                     Info France 3        ...
# 3                       AHMADEKABIR        ...
# 4                            Pollux        ...
# ...                             ...   ...  ...  ..    ...        ...     ...
# 156332               Peuple Révolté        ...
# 156333              Sun☀️ of Afrika        ...
# 156334              Austine nnamani        ...
# 156335                      LeMetek        ...
# 156336  Isaac Saul (readtangle.com)        ...
#
#        retweet_id  reply_to  retweet_date  translate trans_src trans_dest
# 0                        []
# 1                        []
# 2                        []
# 3                        []
# 4                        []
# ...           ...       ...           ...        ...       ...        ...
# 156332                   []
# 156333                   []
# 156334                   []
# 156335                   []
# 156336                   []
#
# [287378 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
sql_df = df[['date', 'time', 'username', 'language',
       'urls', 'tweet', 'replies_count', 'retweets_count', 'likes_count',
       'hashtags', 'video']]

# %%
sql_df

# %%
#contains urls
len(sql_df[sql_df['urls'].map(lambda d: len(d)) > 3])
# Out:
# 38

# %%
#contains video
sum(sql_df['video'])
# Out:
# 119533

# %%
sql_df.to_csv('./data/UkraineRussia_all_with_tweets.csv')
