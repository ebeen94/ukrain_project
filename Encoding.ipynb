# %%
import pandas as pd


df = pd.read_csv('./data/UkraineRussia_all_with_tweets.csv', index_col=0)
df.head(10)
# Out:
# /var/folders/70/pcfbq3d55qd2yhmz04vrn6ph0000gn/T/ipykernel_2671/1933702877.py:4: DtypeWarning: Columns (0,1,2,3,4,5,6,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/UkraineRussia_all_with_tweets.csv', index_col=0)
#          date      time         username language  \
# 0  2022-02-25  13:33:50   zeenewsenglish       en
# 1  2022-02-25  13:33:50  wwiiletterlover       en
# 2  2022-02-25  13:33:49      infofrance3       fr
# 3  2022-02-25  13:33:48      ahmadekabir       fr
# 4  2022-02-25  13:33:48        pollux_hh       en
# 5  2022-02-25  13:33:47        aley_gibi       tr
# 6  2022-02-25  13:33:46  amanphilosopher       en
# 7  2022-02-25  13:33:46  stokstaartje812      und
# 8  2022-02-25  13:33:45         shone_89      und
# 9  2022-02-25  13:33:45       gaoezcetin       de
#
#                                                 urls  \
# 0  ['https://zeenews.india.com/live-updates/russi...
# ...

# %%
df.date.value_counts()
# Out:
# 2022-02-25    336825
# 2022-02-26     71890
# 2022-02-21     61222
# 2022-02-24     43798
# 2022-02-27     20218
# 2022-02-22      1826
# 2022-02-23      1538
# 2022-02-20      1057
# 2022-02-17       460
# 2022-02-28       449
# 2022-02-19       414
# 2022-02-18       364
# 2022-02-16        52
# 1                  5
# 5                  1
# 3                  1
# 4                  1
# 0                  1
# Name: date, dtype: int64

# %%
df.to_csv('./data/Ukraine_all_utf-8.csv', index=False, encoding="utf-8")
